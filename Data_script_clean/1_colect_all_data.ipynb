# %% [markdown]
# # Data collection

# %%
# import df_final_web_data_pt

import pandas as pd

dft1 = pd.read_csv('df_final_web_data_pt_1.txt', engine= 'python')
dft1
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
# import df_final_web_data_pt2

dft2 = pd.read_csv('df_final_web_data_pt_2.txt', engine= 'python')
dft2
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
# concat dft1 with dft2


web_data = pd.concat([dft1, dft2])
web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
# import df_final_demo

dft_demo = pd.read_csv('df_final_demo.txt', engine= 'python')
dft_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
#import df_final_experiment_clients.

dft_exp = pd.read_csv('df_final_experiment_clients.txt', engine= 'python')
dft_exp
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %% [markdown]
# # Data wrangler

# %%
# merge dft_exp with dft_demo

data_merge1 = pd.merge(dft_exp, dft_demo, on='client_id')
data_merge1.head()
# Out:
#    client_id Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0    9988021      Test             5.0              64.0      79.0     U
# 1    8320017      Test            22.0             274.0      34.5     M
# 2    4033851   Control            12.0             149.0      63.5     M
# 3    1982004      Test             6.0              80.0      44.5     U
# 4    9294070   Control             5.0              70.0      29.0     U
#
#    num_accts        bal  calls_6_mnth  logons_6_mnth
# 0        2.0  189023.86           1.0            4.0
# 1        2.0   36001.90           5.0            8.0
# 2        2.0  142642.26           5.0            8.0
# 3        2.0   30231.76           1.0            4.0
# 4        2.0   34254.54           0.0            3.0

# %%
data_merge2 = pd.merge(data_merge1, web_data, on='client_id')
data_merge2.head()
# Out:
#    client_id Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0    9988021      Test             5.0              64.0      79.0     U
# 1    9988021      Test             5.0              64.0      79.0     U
# 2    9988021      Test             5.0              64.0      79.0     U
# 3    9988021      Test             5.0              64.0      79.0     U
# 4    9988021      Test             5.0              64.0      79.0     U
#
#    num_accts        bal  calls_6_mnth  logons_6_mnth            visitor_id  \
# 0        2.0  189023.86           1.0            4.0  580560515_7732621733
# 1        2.0  189023.86           1.0            4.0  580560515_7732621733
# 2        2.0  189023.86           1.0            4.0  580560515_7732621733
# 3        2.0  189023.86           1.0            4.0  580560515_7732621733
# 4        2.0  189023.86           1.0            4.0  580560515_7732621733
#
#                        visit_id process_step            date_time
# ...

# %%
data_merge2.gendr.unique()
# Out:
# array(['U', 'M', 'F', nan, 'X'], dtype=object)

# %%
data_merge2= data_merge2.drop(data_merge2[data_merge2['gendr'] == "X"].index)

# %%
data_merge2.gendr.value_counts()
# Out:
# gendr
# M    151877
# U    151608
# F    146217
# Name: count, dtype: int64

# %%
data_merge2.isnull().sum()
# Out:
# client_id                0
# Variation           128516
# clnt_tenure_yr         115
# clnt_tenure_mnth       115
# clnt_age               127
# gendr                  115
# num_accts              115
# bal                    115
# calls_6_mnth           115
# logons_6_mnth          115
# visitor_id               0
# visit_id                 0
# process_step             0
# date_time                0
# dtype: int64

# %%
data_merge3 = data_merge2.dropna(subset=['clnt_tenure_yr'])

# %%
data_merge3.isnull().sum()
# Out:
# client_id                0
# Variation           128503
# clnt_tenure_yr           0
# clnt_tenure_mnth         0
# clnt_age                12
# gendr                    0
# num_accts                0
# bal                      0
# calls_6_mnth             0
# logons_6_mnth            0
# visitor_id               0
# visit_id                 0
# process_step             0
# date_time                0
# dtype: int64

# %%
data_merge4 = data_merge2.dropna(subset=['clnt_age'])

# %%
data_merge4.isnull().sum()
# Out:
# client_id                0
# Variation           128503
# clnt_tenure_yr           0
# clnt_tenure_mnth         0
# clnt_age                 0
# gendr                    0
# num_accts                0
# bal                      0
# calls_6_mnth             0
# logons_6_mnth            0
# visitor_id               0
# visit_id                 0
# process_step             0
# date_time                0
# dtype: int64

# %%
All_data = data_merge4

# %%
All_data.head()
# Out:
#    client_id Variation  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  \
# 0    9988021      Test             5.0              64.0      79.0     U
# 1    9988021      Test             5.0              64.0      79.0     U
# 2    9988021      Test             5.0              64.0      79.0     U
# 3    9988021      Test             5.0              64.0      79.0     U
# 4    9988021      Test             5.0              64.0      79.0     U
#
#    num_accts        bal  calls_6_mnth  logons_6_mnth            visitor_id  \
# 0        2.0  189023.86           1.0            4.0  580560515_7732621733
# 1        2.0  189023.86           1.0            4.0  580560515_7732621733
# 2        2.0  189023.86           1.0            4.0  580560515_7732621733
# 3        2.0  189023.86           1.0            4.0  580560515_7732621733
# 4        2.0  189023.86           1.0            4.0  580560515_7732621733
#
#                        visit_id process_step            date_time
# ...

# %% [markdown]
# **DataMeta**

# %%
"""
client_id:       Every client's unique ID.
variation:       Indicates if a client was part of the experiment.
visitor_id:      A unique ID for each client-device combination.
visit_id:        A unique ID for each web visit/session.
process_step:    Marks each step in the digital process.
date_time:       Timestamp of each web activity.
clnt_tenure_yr:  Represents how long the client has been with Vanguard, measured in years.
clnt_tenure_mnth: Further breaks down the client's tenure with Vanguard in months.
clnt_age:        Indicates the age of the client.
gendr:           Specifies the client's gender.
num_accts:       Denotes the number of accounts the client holds with Vanguard.
bal:             Gives the total balance spread across all accounts for a particular client.
calls_6_mnth:    Records the number of times the client reached out over a call in the past six months.
logons_6_mnth:   Reflects the frequency with which the client logged onto Vanguard's platform over the last six months
"""
# Out:
# "\nclient_id:       Every client's unique ID.\nvariation:       Indicates if a client was part of the experiment.\nvisitor_id:      A unique ID for each client-device combination.\nvisit_id:        A unique ID for each web visit/session.\nprocess_step:    Marks each step in the digital process.\ndate_time:       Timestamp of each web activity.\nclnt_tenure_yr:  Represents how long the client has been with Vanguard, measured in years.\nclnt_tenure_mnth: Further breaks down the client's tenure with Vanguard in months.\nclnt_age:        Indicates the age of the client.\ngendr:           Specifies the client's gender.\nnum_accts:       Denotes the number of accounts the client holds with Vanguard.\nbal:             Gives the total balance spread across all accounts for a particular client.\ncalls_6_mnth:    Records the number of times the client reached out over a call in the past six months.\nlogons_6_mnth:   Reflects the frequency with which the client logged onto Vanguard's platform o
# ...

# %% [markdown]
# **Save Data in new files**

# %%
#All_data.to_excel('All_data.xlsx', index=False)
#All_data.to_csv('All_data.csv', index=False)
